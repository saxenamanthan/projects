# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# !pip install seaborn

# %%
df = pd.read_csv('/content/heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df['Age']
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
sns.displot(df['Age'])

# %% [markdown]
# ## Distribution Plot for Numeric Columns

# %%
sns.distplot(df['Age'],kde= True , hist = True)
# Out:
# /tmp/ipython-input-2628043518.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde= True , hist = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],kde= True , rug = True)
# Out:
# /tmp/ipython-input-1745362692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde= True , rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'], kde = True)
# Out:
# /tmp/ipython-input-2375152095.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], kde = True)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'], kde = True)
# Out:
# /tmp/ipython-input-321620990.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], kde = True)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'], kde = True)
# Out:
# /tmp/ipython-input-2876310824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], kde = True)
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# # Pie Charts for Categorical

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Sex'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(x = df['HeartDisease'], y = df['Age'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
 sns.violinplot(x = df['HeartDisease'], y = df['Cholesterol'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# # Correlation & Heat Maps

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.select_dtypes(include=np.number).corr())
# Out:
# <Axes: >

# %% [markdown]
# # JointPlot

# %%
sns.jointplot(x = df['Age'], y = df['MaxHR'], kind = 'hex')

# %%
sns.jointplot(x = df['Age'], y = df['Age'])

# %%
sns.jointplot(x = df['HeartDisease'], y = df['Oldpeak'])

# %%
sns.jointplot(x = df['Age'], y = df['MaxHR'], kind = 'reg')

# %%
sns.jointplot(x = df['Cholesterol'], y = df['FastingBS'], kind = 'reg')

# %%
sns.jointplot(x = df['HeartDisease'], y = df['MaxHR'], kind = 'reg')

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)
