# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Electricity_Consumption1.csv')

# %%
df
# Out:
#          Month       City                  Company  Total Monthly Hours
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 7017  February   Vadodara         Adani Power Ltd.               771.12
# 7018     April   Vadodara             Orient Green              1407.60
# 7019       May   Vadodara          Indowind Energy              1768.00
# 7020    August   Vadodara             Orient Green               986.85
# 7021  November   Vadodara  Tata Power Company Ltd.               979.20
#
# [7022 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7022 entries, 0 to 7021
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                7022 non-null   object
#  1   City                 7020 non-null   object
#  2   Company              7022 non-null   object
#  3   Total Monthly Hours  7019 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 219.6+ KB

# %%
df.isnull().sum()
# Out:
# Month                  0
# City                   2
# Company                0
# Total Monthly Hours    3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(40)

# %%
df[df.duplicated()]
# Out:
#           Month         City                  Company  Total Monthly Hours
# 348       March    Ahmedabad          Indowind Energy              712.000
# 386    December    Ahmedabad  Tata Power Company Ltd.              969.600
# 699       March      Chennai          Reliance Energy             1174.250
# 722     October      Chennai          Reliance Energy              931.000
# 804       March      Chennai          Indowind Energy             1025.500
# 936      August        Dahej          Reliance Energy              954.450
# 1102       July        Dahej  Tata Power Company Ltd.             2923.200
# 1269      April        Dahej         Adani Power Ltd.             2056.950
# 1283     August        Dahej         Adani Power Ltd.             1694.700
# 1580     August    Faridabad         Adani Power Ltd.             1590.000
# 1775        May      Gurgaon             Orient Green             1238.600
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6982 entries, 0 to 7021
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                6982 non-null   object
#  1   City                 6980 non-null   object
#  2   Company              6982 non-null   object
#  3   Total Monthly Hours  6979 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 272.7+ KB

# %%
# duplicates helps in removing duplicates from the data

# %%
df.isna().sum()
# Out:
# Month                  0
# City                   2
# Company                0
# Total Monthly Hours    3
# dtype: int64

# %%
 df['City'].nunique()

 df['City'].value_counts()
# Out:
# City
# Ratnagiri      482
# Noida          470
# Kolkata        447
# New Delhi      447
# Gurgaon        446
# Dahej          445
# Hyderabad      443
# Navi Mumbai    442
# Vadodara       436
# Chennai        424
# Mumbai         424
# Ahmedabad      423
# Faridabad      422
# Shimla         419
# Nagpur         408
# Pune           402
# Name: count, dtype: int64

# %%
# Exploratory Data Analysis via addressing the Stakeholder Questions

# Q1. Calculate the Electricity bill for the shared observations

# %%
df1 = pd.read_csv('/content/Tariff_rates.csv')

# %%
df1.head()
# Out:
#         City  TariffRate
# 0  Ahmedabad         7.9
# 1    Chennai         8.8
# 2      Dahej         7.6
# 3  Faridabad         8.1
# 4    Gurgaon         8.3

# %%
electricity_bill = pd.merge(df,df1,how = 'inner', on = 'City')

# %%
electricity_bill
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6976     April   Vadodara             Orient Green              1407.60
# 6977       May   Vadodara          Indowind Energy              1768.00
# 6978    August   Vadodara             Orient Green               986.85
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate
# 0            7.9
# 1            7.9
# 2            7.9
# 3            7.9
# ...

# %%
electricity_bill['TariffRate'].nunique()
# Out:
# 16

# %%
electricity_bill.isna().sum()
# Out:
# Month                  0
# City                   0
# Company                0
# Total Monthly Hours    3
# TariffRate             0
# dtype: int64

# %%
electricity_bill['Bill']=electricity_bill['Total Monthly Hours']*electricity_bill['TariffRate']

# %%
electricity_bill
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 0     November  Ahmedabad          Indowind Energy               367.20
# 1         June  Ahmedabad             Orient Green              1179.00
# 2      October  Ahmedabad          Indowind Energy               477.00
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# ...        ...        ...                      ...                  ...
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6976     April   Vadodara             Orient Green              1407.60
# 6977       May   Vadodara          Indowind Energy              1768.00
# 6978    August   Vadodara             Orient Green               986.85
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate       Bill
# 0            7.9   2900.880
# 1            7.9   9314.100
# ...

# %%
# Q2 Calculate the average monthly hours of the usage for the cities in Descending order

# %%
#groupby never works without aggregation

electricity_bill.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending=False)
# Out:
# City
# Noida          1601.452851
# New Delhi      1599.586409
# Gurgaon        1467.559574
# Ahmedabad      1252.175297
# Dahej          1251.822270
# Faridabad      1220.659005
# Chennai        1113.937884
# Vadodara       1106.086869
# Hyderabad      1076.999695
# Nagpur          959.219608
# Mumbai          876.044552
# Navi Mumbai     777.384615
# Pune            739.073582
# Kolkata         629.435123
# Ratnagiri       530.865809
# Shimla          313.066050
# Name: Total Monthly Hours, dtype: float64

# %%
# Visualizing the solution for the Q2

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,9), dpi = 300)
plt.bar(electricity_bill.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1290126496.py in <cell line: 0>()
#       5
#       6 plt.figure(figsize=(20,9), dpi = 300)
# ----> 7 plt.bar(electricity_bill.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending=False))
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.figure(figsize=(20,9), dpi = 300)

sns.barplot(electricity_bill.groupby('City')['Total Monthly Hours'].mean().sort_values(ascending=False))
# Out:
# <Axes: xlabel='City', ylabel='Total Monthly Hours'>

# %%
# Q3. What are the top 3 companies in terms of average monthly hours of electricity usage

electricity_bill.groupby('Company')['Total Monthly Hours'].mean().sort_values(ascending=False).head(3)
# Out:
# Company
# Indowind Energy            1059.862618
# Orient Green               1053.577907
# Tata Power Company Ltd.    1035.275307
# Name: Total Monthly Hours, dtype: float64

# %%
sns.barplot(electricity_bill.groupby('Company')['Total Monthly Hours'].mean().sort_values(ascending=False).head(3))
# Out:
# <Axes: xlabel='Company', ylabel='Total Monthly Hours'>

# %%
# Q4. Which are the cities with highest Electricity Bill

electricity_bill.groupby('City')['Bill'].sum().sort_values(ascending = False)
# Out:
# City
# Noida          6.171999e+06
# New Delhi      6.077629e+06
# Gurgaon        5.432612e+06
# Dahej          4.233663e+06
# Faridabad      4.172457e+06
# Ahmedabad      4.164610e+06
# Chennai        4.146522e+06
# Hyderabad      4.007731e+06
# Vadodara       3.761580e+06
# Nagpur         3.483118e+06
# Mumbai         3.417275e+06
# Navi Mumbai    3.195517e+06
# Pune           2.703679e+06
# Kolkata        2.447810e+06
# Ratnagiri      1.893492e+06
# Shimla         1.010045e+06
# Name: Bill, dtype: float64

# %%
# H.W < How to remove these higher order of Magnitude from the output?

# %%
sns.scatterplot(electricity_bill.groupby('City')['Bill'].sum().sort_values(ascending = False))
# Out:
# <Axes: xlabel='City', ylabel='Bill'>

# %%
sns.scatterplot(x= electricity_bill['Total Monthly Hours'], y = electricity_bill['Bill'])
# Out:
# <Axes: xlabel='Total Monthly Hours', ylabel='Bill'>

# %%
electricity_bill['Company'].unique()
# Out:
# array(['Indowind Energy', 'Orient Green', 'Tata Power Company Ltd.',
#        'Adani Power Ltd.', 'Reliance Energy'], dtype=object)

# %%
#Q5. In which city the electricity consumption is more for Tata power than that of Adani power

# %%
results = electricity_bill[(electricity_bill['Company']=='Tata Power Company Ltd.') | (electricity_bill['Company']=='Adani Power Ltd.')]

# %%
results
# Out:
#          Month       City                  Company  Total Monthly Hours  \
# 3     December  Ahmedabad  Tata Power Company Ltd.               393.60
# 4          May  Ahmedabad         Adani Power Ltd.               672.00
# 6          May  Ahmedabad  Tata Power Company Ltd.              1290.00
# 7     December  Ahmedabad  Tata Power Company Ltd.               310.40
# 8         July  Ahmedabad  Tata Power Company Ltd.              1821.00
# ...        ...        ...                      ...                  ...
# 6970      July   Vadodara  Tata Power Company Ltd.              2769.30
# 6971  December   Vadodara  Tata Power Company Ltd.               656.88
# 6973     April   Vadodara  Tata Power Company Ltd.              1259.70
# 6975  February   Vadodara         Adani Power Ltd.               771.12
# 6979  November   Vadodara  Tata Power Company Ltd.               979.20
#
#       TariffRate       Bill
# 3            7.9   3109.440
# 4            7.9   5308.800
# ...

# %%
results['Company'].unique()
# Out:
# array(['Tata Power Company Ltd.', 'Adani Power Ltd.'], dtype=object)

# %%
plt.figsize(figsize=(20,9), dpi = 300)
sns.barplot(x= results['Total Monthly Hours'], y= results['City'], hue = results['Company'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1856223801.py in <cell line: 0>()
# ----> 1 plt.figsize(figsize=(20,9), dpi = 300)
#       2 sns.barplot(x= results['Total Monthly Hours'], y= results['City'], hue = results['Company'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
# Q6. Which cities shows the maximum range of usage?

electricity_bill.describe()
# Out:
#        Total Monthly Hours   TariffRate          Bill
# count          6977.000000  6980.000000   6977.000000
# mean           1035.410689     8.357192   8645.512329
# std             843.128978     0.577082   7001.401856
# min              61.400000     7.400000    472.780000
# 25%             472.260000     7.800000   3951.584000
# 50%             789.360000     8.300000   6635.304000
# 75%            1304.000000     8.800000  10879.830000
# max            6187.500000     9.300000  52593.750000

# %%
sns.boxplot( x= electricity_bill['Total Monthly Hours'], y= electricity_bill['City'])
# Out:
# <Axes: xlabel='Total Monthly Hours', ylabel='City'>
